# %% [markdown]
# # song popularity prediction

# %% [markdown]
# # importing dataset using pandas

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\MADHU\Downloads\archive (4)\top50.csv",encoding="latin1")

# %%
data
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Señorita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
#printing first 5 rows using head()
p=data.head()
p
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
data.tail()
# Out:
#     Unnamed: 0                                     Track.Name  \
# 45          46                                One Thing Right
# 46          47                                      Te Robaré
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name    Genre  Beats.Per.Minute  Energy  Danceability  \
# 45        Marshmello  brostep                88      62            66
# 46         Nicky Jam    latin               176      75            67
# 47        Marshmello  brostep               100      79            69
# 48  The Chainsmokers      edm               104      70            59
# 49        Ed Sheeran      pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 45              -2        58        44      182               7             5
# ...

# %%
#printing column names with their null count
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
#printing no.of rows and columns using shape
data.shape
# Out:
# (50, 14)

# %%
data=data.drop(['Unnamed: 0',"Track.Name"],axis=1)

# %%
print('no.of rows in our dataset:-',data.shape[0])
print('no.of columns in our dataset:-',data.shape[1])
# Out:
# no.of rows in our dataset:- 50
# no.of columns in our dataset:- 12

# %%
data
# Out:
#          Artist.Name             Genre  Beats.Per.Minute  Energy  \
# 0       Shawn Mendes      canadian pop               117      55
# 1           Anuel AA    reggaeton flow               105      81
# 2      Ariana Grande         dance pop               190      80
# 3         Ed Sheeran               pop                93      65
# 4        Post Malone           dfw rap               150      65
# 5         Ed Sheeran               pop               102      68
# 6          Lil Tecca        trap music               180      64
# 7          Sam Smith               pop               111      68
# 8          Lil Nas X       country rap               136      62
# 9      Billie Eilish        electropop               135      43
# 10         Bad Bunny         reggaeton               176      62
# 11          DJ Snake         dance pop                96      71
# 12     Lewis Capaldi               pop               110      41
# ...

# %% [markdown]
# # Data processing

# %% [markdown]
# # Handling missing values

# %%
print("does our dataset contains any missing values:-",data.isnull().values.any())
# Out:
# does our dataset contains any missing values:- False

# %%
data.isnull()
# Out:
#     Artist.Name  Genre  Beats.Per.Minute  Energy  Danceability  \
# 0         False  False             False   False         False
# 1         False  False             False   False         False
# 2         False  False             False   False         False
# 3         False  False             False   False         False
# 4         False  False             False   False         False
# 5         False  False             False   False         False
# 6         False  False             False   False         False
# 7         False  False             False   False         False
# 8         False  False             False   False         False
# 9         False  False             False   False         False
# 10        False  False             False   False         False
# 11        False  False             False   False         False
# 12        False  False             False   False         False
# 13        False  False             False   False         False
# ...

# %%
import seaborn as sns
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing duplicates

# %%
dup_data=data.duplicated().any()
print("are there any duplicate values in our dataset:-",dup_data)
# Out:
# are there any duplicate values in our dataset:- False

# %%
#if there is any duplicate values we can drop them as
data=data.drop_duplicates()
data
# Out:
#          Artist.Name             Genre  Beats.Per.Minute  Energy  \
# 0       Shawn Mendes      canadian pop               117      55
# 1           Anuel AA    reggaeton flow               105      81
# 2      Ariana Grande         dance pop               190      80
# 3         Ed Sheeran               pop                93      65
# 4        Post Malone           dfw rap               150      65
# 5         Ed Sheeran               pop               102      68
# 6          Lil Tecca        trap music               180      64
# 7          Sam Smith               pop               111      68
# 8          Lil Nas X       country rap               136      62
# 9      Billie Eilish        electropop               135      43
# 10         Bad Bunny         reggaeton               176      62
# 11          DJ Snake         dance pop                96      71
# 12     Lewis Capaldi               pop               110      41
# ...

# %% [markdown]
# # Data summarizing

# %%
data.describe()
# Out:
#        Beats.Per.Minute     Energy  Danceability  Loudness..dB..   Liveness  \
# count         50.000000  50.000000      50.00000       50.000000  50.000000
# mean         120.060000  64.060000      71.38000       -5.660000  14.660000
# std           30.898392  14.231913      11.92988        2.056448  11.118306
# min           85.000000  32.000000      29.00000      -11.000000   5.000000
# 25%           96.000000  55.250000      67.00000       -6.750000   8.000000
# 50%          104.500000  66.500000      73.50000       -6.000000  11.000000
# 75%          137.500000  74.750000      79.75000       -4.000000  15.750000
# max          190.000000  88.000000      90.00000       -2.000000  58.000000
#
#         Valence.     Length.  Acousticness..  Speechiness.  Popularity
# count  50.000000   50.000000       50.000000     50.000000   50.000000
# mean   54.600000  200.960000       22.160000     12.480000   87.500000
# std    22.336024   39.143879       18.995553     11.161596    4.491489
# ...

# %% [markdown]
# # converting genre into integer data

# %%
b={'canadian pop':0,'reggaeton flow':1,'dance pop':2,'dfw rap':3,'trap music':4,'country rap':5,'electropop':6,'reggaeton':7,'panamanian pop':8,'canadian hip hop':9,'latin':10,
  'escape room':11,'pop house':12,'australian pop':13,'edm':14,'atl hip hop':15,'big room':16,'boy band':17,'r&b en espanol':18,'brostep':19,'pop':20}
data['Genre']=data['Genre'].map(b)
data
# Out:
#          Artist.Name  Genre  Beats.Per.Minute  Energy  Danceability  \
# 0       Shawn Mendes      0               117      55            76
# 1           Anuel AA      1               105      81            79
# 2      Ariana Grande      2               190      80            40
# 3         Ed Sheeran     20                93      65            64
# 4        Post Malone      3               150      65            58
# 5         Ed Sheeran     20               102      68            80
# 6          Lil Tecca      4               180      64            75
# 7          Sam Smith     20               111      68            48
# 8          Lil Nas X      5               136      62            88
# 9      Billie Eilish      6               135      43            70
# 10         Bad Bunny      7               176      62            61
# 11          DJ Snake      2                96      71            82
# 12     Lewis Capaldi     20               110      41            50
# ...

# %% [markdown]
# # assigning data set to X and Y

# %%
y = data.loc[:, 'Popularity']
x = data.drop(['Popularity','Artist.Name'], axis=1)
x1=x.head()
x1
# Out:
#    Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 0      0               117      55            76              -6         8
# 1      1               105      81            79              -4         8
# 2      2               190      80            40              -4        16
# 3     20                93      65            64              -8         8
# 4      3               150      65            58              -4        11
#
#    Valence.  Length.  Acousticness..  Speechiness.
# 0        75      191               4             3
# 1        61      302               8             9
# 2        70      186              12            46
# 3        55      198              12            19
# 4        18      175              45             7

# %%
y1=y.head()
y1
# Out:
# 0    79
# 1    92
# 2    85
# 3    86
# 4    94
# Name: Popularity, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.bar(p["Beats.Per.Minute"],y1,label="Beats.Per.Minute")  
plt.bar(p["Energy"],y1,label="Energy")
plt.bar(p["Danceability"],y1,label="Danceability")
plt.bar(p["Loudness..dB.."],y1,label="Loudness..dB..")
plt.bar(p["Liveness"],y1,label="Liveness")
plt.bar(p["Valence."],y1,label="Valence.")
plt.bar(p["Length."],y1,label="Length.")
plt.bar(p["Acousticness.."],y1,label="Acousticness..")
plt.bar(p["Speechiness."],y1,label="Speechiness.")
plt.legend()

# %% [markdown]
# # REGRESSION MODEL

# %%
#according to our dataset here we have to use multiple linear regression
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([ 0.04595599,  0.01002815,  0.01298908,  0.0164295 ,  0.14912983,
#         0.05291037, -0.07136405, -0.01510338, -0.00664122,  0.09885487])

# %%
model.intercept_
# Out:
# 89.76446606449286

# %%
#Y=B0+B1X1+B2X2+B3X3+---+BnXn
0.04595599*20+ 0.01002815*93+ 0.01298908*65+ 0.0164295*64 + 0.14912983*-8+0.05291037*8+ -0.07136405*55+ -0.01510338*198+ -0.00664122*12+0.09885487*19+89.76446606449286
# Out:
# 87.62528223449286

# %%
model.predict([[20,93,65,64,-8,8,55,198,12,19]])
# Out:
# C:\Users\MADHU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([87.62528178])

# %%
#from the above 2 lines of code the obtained popularity by the linear regression model and linear regreesion equation are closure to each other

# %% [markdown]
# # traing and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_train
# Out:
#     Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 32      7                96      71            78              -5         9
# 39      2                95      56            81              -6         6
# 21      5               154      59            70              -6        12
# 36      8               176      70            75              -5        11
# 19     11               158      62            72              -3        12
# 42      2                96      39            57              -6        23
# 49     20                95      79            75              -6         7
# 26     13                98      59            82              -6        18
# 22      1                92      79            81              -4         9
# 13      8               176      79            73              -2         6
# 41      2                85      68            77              -6         7
# ...

# %%
x_test
# Out:
#     Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 27      9                96      46            73              -7        19
# 35     16               114      72            66              -7        14
# 40     14               104      68            69              -7        10
# 38     17               138      73            84              -5        11
# 2       2               190      80            40              -4        16
# 3      20                93      65            64              -8         8
# 48     14               104      70            59              -6        41
# 29     10                93      79            64              -4        36
# 46     10               176      75            67              -4         8
# 31      2               140      32            78             -11         9
#
#     Valence.  Length.  Acousticness..  Speechiness.
# 27        40      213              37             3
# ...

# %%
import numpy as np
m=np.array(y_test).reshape(-1, 1)
m
# Out:
# array([[89],
#        [89],
#        [88],
#        [80],
#        [85],
#        [86],
#        [88],
#        [89],
#        [88],
#        [89]], dtype=int64)

# %%
y_pred=np.array(reg.predict(x_test)).reshape(-1, 1)
print(y_pred)
# Out:
# [[85.5188064 ]
#  [88.63137876]
#  [86.05302616]
#  [85.56059539]
#  [95.13398144]
#  [88.44686539]
#  [87.36136944]
#  [89.54556865]
#  [85.99544746]
#  [89.48556766]]

# %%
#finding error
from sklearn.metrics import mean_absolute_error as mae
print(mae(y_test,y_pred))
# Out:
# 2.761255031057831

# %%
error=m-y_pred
error
# Out:
# array([[  3.4811936 ],
#        [  0.36862124],
#        [  1.94697384],
#        [ -5.56059539],
#        [-10.13398144],
#        [ -2.44686539],
#        [  0.63863056],
#        [ -0.54556865],
#        [  2.00455254],
#        [ -0.48556766]])

# %%
#mean square error E=mean(y_actual-y_predict)^2
a=3.481194+0.368621+1.946974+-5.560595+-10.133981+-2.446865+0.638631+ -0.545569+2.004553+-0.485568
b=a/10
c=b*b
c
# Out:
# 1.1518881008602504

# %%
import sklearn.metrics as sm
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, y_pred), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, y_pred), 2)) 
print("***Median absolute error***=", round(sm.median_absolute_error(y_test, y_pred), 2))
# Out:
# Mean absolute error = 2.76
# Mean squared error = 16.06
# ***Median absolute error***= 1.98

# %%
model.predict([[0,117,55,76,-6,8,75,191,4,3]])
# Out:
# C:\Users\MADHU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([84.46225507])

# %%
model.predict([[7,176,62,61,-5,24,24,251,60,31]])#actual value is 93
# Out:
# C:\Users\MADHU\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([91.34517605])
